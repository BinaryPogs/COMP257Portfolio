# %% [markdown]
# # Portfolio 3 - Clustering Visualisation

# %% [markdown]
# K-means clustering is one of the simplest and popular unsupervised learning algorithms. Typically, unsupervised algorithms make inferences from datasets using only input vectors without referring to known, or labelled, outcomes. This notebook illustrates the process of K-means clustering by generating some random clusters of data and then showing the iterations of the algorithm as random cluster means are updated.

# %% [markdown]
# We first generate random data around 4 centers.

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
center_1 = np.array([1,2])
center_2 = np.array([6,6])
center_3 = np.array([9,1])
center_4 = np.array([-5,-1])

# Generate random data and center it to the four centers each with a different variance
np.random.seed =5
data_1 = np.random.randn(200,2) * 1.5 + center_1
data_2 = np.random.randn(200,2) * 1 + center_2
data_3 = np.random.randn(200,2) * 0.5 + center_3
data_4 = np.random.randn(200,2) * 0.8 + center_4

data = np.concatenate((data_1, data_2, data_3, data_4), axis = 0)

plt.scatter(data[:,0], data[:,1], s=7, c='k')
plt.show()

# %% [markdown]
# ## 1. Generate random cluster centres
#
# You need to generate four random centres.
#
# This part of portfolio should contain at least:
# - The number of clusters `k` is set to 4;
# - Generate random centres via `centres = np.random.randn(k,c)*std + mean` where `std` and `mean` are the standard deviation and mean of the data. `c` represents the number of features in the data. Set the random seed to 6.
# - Color the generated centers with `green`, `blue`, `yellow`, and `cyan`. Set the edgecolors to `red`.

# %%
def createCentres(k,c,data,seed=6):
    np.random.seed = seed
    centres = np.random.randn(k,c)*np.std(data)+np.mean(data)
    return centres

def getClosestCentroid(point, centres):
    dist = []
    for c in centres:
        dist.append(np.linalg.norm(point-c))
    return dist.index(min(dist))

centres = createCentres(4,2,data)  
getClosestCentroid(data[0], centres)
centres
# Out:
# array([[ 3.43022628, -3.17849318],
#        [ 3.45631767,  4.76446347],
#        [ 2.48799848,  2.96047887],
#        [ 3.72928271,  3.04789615]])

# %%
x,y = data[:,0],data[:,1]

# %%
colours = ['g','b','y','c']
def getCluster(data,centres):
    cluster = []
    for point in data:
        cluster.append(getClosestCentroid(point,centres))
    return cluster

df = pd.DataFrame(data, columns=['x','y'])
c = getCluster(data,centres)
df = pd.DataFrame({'x':x,'y':y,'clusters':c})    
sns.scatterplot(x='x',y='y',hue='clusters',data=df,palette=colours)

# %% [markdown]
# ## 2. Visualise the clustering results in each iteration

# %% [markdown]
# You need to implement the process of k-means clustering.  Implement each iteration as a seperate cell, assigning each data point to the closest centre, then updating the cluster centres based on the data, then plot the new clusters.
#
# Replace this text with your explaination of the algorithm.  The resulting notebook should provide a good explanation and demonstration of the K-means algorithm.

# %%
# Out:
# array([ 1.15314374, -0.77078769,  2.39369015,  1.51793637,  0.6043461 ,
#         1.42386944,  2.55743905,  1.25428219, -0.77740664,  2.74200619,
#         1.91256871,  2.28877683, -2.22032419,  1.36049822,  0.9575659 ,
#        -0.61936043, -0.41699475,  1.97076257,  0.51606693,  1.17071022,
#         1.71432117,  0.6224387 ,  1.70757953,  3.00289473, -0.9129834 ,
#         1.5938696 ,  1.87266921,  2.10958583,  3.04683236,  3.7745245 ,
#         0.36592495, -0.92042663,  2.35124122,  3.29071926,  0.67577691,
#        -0.12678256,  1.76003732, -0.06161672,  2.41427783,  1.77966774,
#         1.93343059,  2.50512273,  4.89165989,  2.50649849,  0.81590666,
#         2.22935195,  2.02060401,  3.85652187,  0.71277703,  0.78726177,
#         3.67365605,  0.75606045,  0.08869869, -0.86237091, -0.93937402,
#         1.47549498, -0.01671347,  1.41157107,  1.56329436,  0.35764556,
#         0.60821153,  1.74342205,  1.78951562,  5.34909912, -0.96134251,
#        -1.18191753,  1.29139235,  0.70857389, -0.39015763,  2.15617784,
#         1.57982907,  0.98252896, -1.09623269,  4.51905114,  1.08836719,
#        -0.46150358, -0.50844628,  1.03449032,  0.0192233 ,  0.14739691,
#         0.27625497,  2.92222739,  3.2274339 ,  1.02711077, -1.084693  ,
#        -1.37120289, -0.85458369,  0.7841457 ,  3.75062862,  2.64330491,
#         1.08503014,  0.28132188,  0.21470691,  2.08671301,  1.21004463,
#         1.3358922 ,  2.31744235,  0.39042928, -1.13226298,  2.55606658,
#         0.42579859, -0.40113111, -0.68081755, -2.16333259,  0.97108781,
#         1.26462869,  0.08050779,  0.71839575,  2.25883472, -0.05155528,
#         3.33504985,  3.99530475, -0.86101836, -0.09139035,  1.5643712 ,
#         0.33890974, -0.47394869, -1.25016069,  0.66422138,  0.19776173,
#         4.49609447,  2.16882701,  2.63468089,  2.26695209,  0.07018254,
#        -0.49068735,  0.71405588,  0.65136999,  3.96026384, -1.6199808 ,
#         1.10818283,  3.06677733,  0.24980355,  1.99911585,  0.90979922,
#         1.43243161, -0.76350827,  1.89798568,  3.80139714,  3.85534496,
#         1.15918482,  2.16468407,  3.26486062, -1.77035525,  2.4222197 ,
#         0.09923342,  1.07543024, -0.30057367,  2.24656556,  3.10875609,
#        -0.27258828, -0.83054655,  1.90993916,  2.73659446,  1.96829344,
#         2.70626474, -0.06517216,  0.59830741,  1.66007953, -0.17480055,
#        -0.36561601,  1.89898687,  1.42489231, -0.17275122,  4.17142385,
#        -0.80478782,  4.70362785,  0.70509813,  1.06223337,  0.83650879,
#         0.68746292,  2.75329922,  0.3790106 ,  0.9808004 ,  1.31643329,
#         1.27140331,  1.8638786 ,  1.64348002,  0.14844838,  0.43400615,
#         1.08083557,  1.31312536, -0.4934966 ,  2.72479449,  0.97964017,
#        -0.67922143,  1.64268642, -0.47037686,  2.7945683 ,  0.2868938 ,
#        -0.19206659, -0.04456351,  2.76672296,  2.03943938, -0.56254997,
#         3.86897031,  2.25111501, -3.22690171,  1.03272683, -1.76651331,
#         6.94478966,  7.63322722,  6.04873881,  6.52067772,  5.00469051,
#         4.70677062,  6.7434714 ,  7.19167773,  7.52738252,  8.68055635,
#         5.4997076 ,  4.64564164,  5.55873344,  5.16677443,  7.61053471,
#         3.66664191,  4.28528584,  5.60563809,  5.0541939 ,  6.78635658,
#         6.03305254,  5.2313123 ,  6.28799848,  5.13355026,  7.82351022,
#         5.96750926,  7.34687953,  6.56185248,  7.10377139,  7.43080598,
#         4.92171461,  4.66064039,  6.48378544,  5.36602828,  5.39689151,
#         5.8017755 ,  6.86071835,  6.83389273,  6.4286089 ,  6.89556625,
#         6.58565607,  5.63331746,  6.05977737,  5.33147872,  6.10976838,
#         7.03961834,  7.05832416,  5.71709363,  6.40067227,  6.28698219,
#         7.40853371,  4.7767332 ,  6.28568093,  4.5306323 ,  5.53692983,
#         5.57990227,  6.8066692 ,  4.97383878,  6.43452767,  6.50414922,
#         6.90125988,  5.22484629,  5.92543887,  6.82811468,  5.51387236,
#         6.76699357,  6.57125693,  6.76460026,  7.02677765,  7.06009329,
#         6.14098498,  5.73789673,  5.05331376,  5.32726312,  7.11022866,
#         5.6392862 ,  5.26780591,  6.07788726,  5.90867749,  5.80399052,
#         6.73806975,  4.97676053,  5.71268241,  6.57640715,  6.52253997,
#         5.87862979,  5.75579333,  6.17743334,  5.83142994,  5.58896573,
#         7.36358488,  5.09585657,  6.18934498,  5.38655276,  6.4424007 ,
#         6.34192811,  6.82596228,  6.19878092,  4.77407646,  6.31846368,
#         6.15391787,  5.4978633 ,  5.66430486,  6.90626403,  6.54542319,
#         4.93098994,  5.8814318 ,  6.40914625,  6.910309  ,  6.78309804,
#         5.38464239,  6.24886   ,  6.97710553,  6.68458851,  7.60299738,
#         5.6415671 ,  6.13657436,  5.07265067,  5.66487825,  6.4816399 ,
#         5.74978454,  6.26672177,  5.92394256,  7.1145701 ,  6.19755504,
#         5.07817617,  6.86241147,  4.72909187,  5.26302364,  7.71360864,
#         5.25094903,  7.09132926,  5.56366245,  5.79357463,  6.41826826,
#         6.81842542,  5.4860787 ,  6.58590819,  6.70778717,  6.29667419,
#         5.60064604,  7.02410214,  6.59344916,  7.64112649,  8.47426123,
#         6.70348752,  6.83090071,  8.27648739,  4.4045302 ,  5.50582075,
#         6.40948129,  7.15662421,  6.60400452,  5.99539048,  5.75650606,
#         5.63539264,  7.12043339,  6.74279178,  7.25189945,  5.70757468,
#         6.80405287,  5.57308337,  5.90460871,  6.96868299,  6.35484699,
#         7.53360287,  6.78229715,  6.37521059,  6.30371263,  4.92822087,
#         6.95561458,  6.0442113 ,  5.25177446,  5.24388625,  5.89355707,
#         8.07150488,  5.20497224,  5.23503155,  5.68627898,  6.47501759,
#         6.1086655 ,  6.53695998,  6.22884919,  5.75691673,  7.5936594 ,
#         5.16882555,  5.06508209,  4.8326887 ,  3.32385429,  4.93923627,
#         5.75465946,  6.88679144,  6.39084173,  6.80266052,  7.88450702,
#         7.99699864,  4.92607545,  6.29706586,  6.72983211,  4.84006598,
#         9.53653045,  8.18038692,  8.2376422 ,  8.78682388,  9.13213037,
#         9.4294214 ,  9.45060369,  9.43491896,  8.7188606 ,  8.45377545,
#         9.13760525,  9.03119127,  9.23020393,  9.81119078,  8.48384015,
#         9.91645325,  8.63134692,  9.71034309,  9.24994178,  8.95998356,
#         9.59960261,  9.02852877,  9.20525997,  8.33467024,  9.28212582,
#         8.40184678,  9.78809204,  8.37790162,  8.13719752,  9.40727878,
#         9.52483174,  8.80784524,  9.05968516,  9.22218346,  8.11427604,
#         9.04319148,  9.41077469,  8.04384158,  8.62097212,  9.02238263,
#         9.00977705,  8.56747142,  9.35221799,  8.97182202,  8.51050935,
#         9.2518226 ,  8.49084687,  9.81121983,  9.16977065,  9.45129922,
#         8.54783758,  9.42878929,  8.17019632,  8.7877164 ,  8.80283846,
#         9.40588825,  8.46649873,  8.06464183,  9.08422984,  9.33027946,
#         8.82072509,  9.33083304,  8.7880196 ,  9.45330863,  9.17549389,
#         9.879687  ,  8.44133937,  8.88445438,  8.38626116,  9.16464426,
#         9.95264001,  9.07161767,  8.87503806,  8.49206834,  9.15563567,
#         8.70070076,  8.74497376,  9.37848836,  8.44796562,  9.96724975,
#         9.06076806,  9.31027375,  9.09503441,  8.37662792,  7.89868893,
#         8.65421988,  8.13369434,  9.57780907,  8.58141501,  8.34777377,
#         8.15723974,  9.83707282,  8.93944907,  9.22494816,  8.37474226,
#         8.08887793,  8.89400629,  9.72108303,  9.84055304,  9.41758362,
#         8.35784188,  9.41633188,  9.46739239,  8.49895639,  8.38537313,
#         8.53408039,  9.45112324,  9.42301043,  9.84430532,  9.1380948 ,
#         9.46247641,  9.03990998,  8.81610159,  8.10479137,  9.14181073,
#        10.19820271,  9.18805465,  8.87389367,  8.73415402,  9.39300061,
#         9.01339804,  9.42869884,  9.81429255,  9.9237822 ,  8.38253731,
#         9.23658135,  8.94186536,  9.70815759, 10.09827359,  8.83623499,
#         9.65856978,  9.22080734,  9.55155875,  8.96664142,  9.08550214,
#         9.63606704,  9.80587962,  8.54351855,  9.23850881,  9.46954972,
#         8.64996525,  9.74416001,  9.12505174,  8.26011432,  8.70501374,
#         8.63469306,  9.44216664,  8.95079412,  8.55588672,  8.85135233,
#         9.20693786,  9.05226888,  9.11100828,  9.86754262,  8.45231785,
#         8.79745243,  8.14230829,  8.71792657,  9.78075692,  8.2255457 ,
#         9.98301334,  8.94502812,  8.58557859,  8.26211803,  9.39235575,
#         9.30521363,  9.5482536 ,  8.60173759,  9.48846469,  8.69605004,
#         9.26239705,  9.41587881, 10.00698973,  8.35912683,  9.86613436,
#         8.58226553,  9.03271841,  8.9088588 ,  9.69441023,  8.6456921 ,
#         8.2587272 ,  8.78570548, 10.08573472,  8.33899896,  8.6052925 ,
#         9.8317172 ,  9.23460249,  8.29254176,  7.89151902,  8.672918  ,
#         9.13264021,  9.98815054,  9.26006844,  9.32032024,  8.79019357,
#         9.80468337,  8.89617138,  9.55304941,  9.22705171,  9.54868693,
#        -5.54728627, -4.09938876, -5.39853257, -3.53240763, -5.37467104,
#        -6.26011411, -5.29563649, -5.2697296 , -4.9170118 , -3.98929154,
#        -5.17453257, -4.91983466, -4.94962448, -4.48202392, -4.54619359,
#        -4.328911  , -4.59617998, -5.1767848 , -3.751473  , -5.71660268,
#        -4.91150704, -4.07105965, -4.68681783, -5.25397781, -4.44837199,
#        -3.56978943, -4.21298156, -4.71650687, -5.84435753, -5.29222461,
#        -4.43167665, -4.86351826, -3.85221825, -5.16176293, -5.04652839,
#        -6.63872654, -4.15777222, -6.66887174, -5.35228714, -5.01484881,
#        -5.198978  , -6.05273599, -4.74103316, -5.48583758, -5.83635528,
#        -6.16978917, -4.96186762, -2.87653293, -3.04998474, -5.68044851,
#        -4.22987715, -4.42160401, -4.41601927, -5.00714968, -4.48945803,
#        -5.48640601, -5.50142248, -4.21112521, -4.24275135, -5.42275962,
#        -5.51567502, -5.87128087, -5.55413568, -5.82133203, -5.48715041,
#        -3.89681986, -4.06674959, -5.19952028, -7.07908638, -6.39390985,
#        -5.85967643, -4.95729416, -5.32156432, -5.6533015 , -4.47818872,
#        -5.91612192, -4.64048724, -6.40110999, -5.63262474, -5.83328147,
#        -4.6695245 , -6.23424251, -4.79407128, -4.90855491, -4.89810394,
#        -5.73842013, -6.41789154, -3.95310074, -4.79084674, -4.15133505,
#        -6.34803527, -6.02912503, -4.63288392, -5.19452547, -5.48334001,
#        -5.39473445, -5.15861598, -4.5463726 , -6.12871253, -3.88504741,
#        -5.01743911, -5.37040066, -5.01128099, -4.95134076, -5.41305127,
#        -5.76284474, -6.16127538, -5.0739586 , -6.37864898, -6.26410169,
#        -4.419865  , -5.54756961, -4.8645174 , -4.78693745, -5.5051838 ,
#        -5.35143338, -3.48887564, -5.65235741, -5.22342893, -4.49562206,
#        -5.45080875, -4.93857034, -5.36526304, -5.49889807, -5.05513042,
#        -8.12927528, -4.82890185, -4.40651829, -5.50598429, -4.79538621,
#        -5.36933855, -6.37455959, -3.30176436, -4.99162857, -3.58385551,
#        -5.93984075, -4.0988931 , -3.43558908, -4.35286418, -5.3558799 ,
#        -4.72217091, -5.96565663, -6.45722972, -5.88722249, -6.13808969,
#        -5.80522244, -4.10478291, -5.61314046, -5.31364075, -6.43328732,
#        -5.01753325, -5.11079864, -5.92392779, -5.10399657, -4.73437946,
#        -5.93972948, -5.25896133, -5.49287396, -4.86028133, -6.71732578,
#        -4.14457247, -5.68997798, -4.01877058, -6.91789328, -4.53419398,
#        -6.19340994, -5.33105589, -4.43231757, -6.10148959, -4.64636584,
#        -4.52436314, -5.13179552, -3.50941863, -4.52291613, -3.97378697,
#        -4.40442269, -5.05478805, -4.88465945, -6.1021059 , -6.54427522,
#        -5.58035777, -4.14724396, -4.53176483, -3.30695965, -2.84195609,
#        -4.74010464, -4.6943602 , -4.89557967, -3.90380946, -4.09271408,
#        -3.99500367, -4.55712138, -5.20434176, -4.34420291, -5.79996439,
#        -4.86515886, -5.09195679, -5.11965517, -4.3486809 , -5.35647085])
